# %%
from scipy import signal
import matplotlib.pyplot as plt
import control as ctl
import numpy as np

# %% [markdown]
# semelhança corresponde a compartilhamento de informção, quanto mais dois sinais compartilham, mais correlação eles apresentam
